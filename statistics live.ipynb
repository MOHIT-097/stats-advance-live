# %% [markdown]
# ## **Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?**

# %% [markdown]
# *Ans:-* The z-statistic is a measure used in statistics to determine how far away a sample mean is from the population mean, expressed in terms of standard deviations. It is calculated using the formula:
# ![Screenshot 2024-10-18 134126.png](data:image/png;base64,...)
# where:
#
#
# * X is the sample mean,
#
# * μ is the population mean,
#
# * σ is the population standard deviation, and
#
# * n is the sample size
#
# ###**Relationship to the Standard Normal Distribution**
#
# The z-statistic follows the standard normal distribution, which has a mean of 0 and a standard deviation of 1. This relationship allows statisticians to use the z-statistic to assess how unusual or extreme a sample mean is compared to the population mean. When the population is normally distributed, or the sample size is large enough for the Central Limit Theorem to apply, the z-statistic can be used effectively.
#
# ###**Use in Hypothesis Testin**
#
# In hypothesis testing, the z-statistic is used to determine whether to reject the null hypothesis (h0). Here’s how it typically works:
#
# 1. **Formulate Hypotheses:** Establish the null hypothesis and an alternative hypothesis (𝐻𝑎).
#
# 2. **Select Significance Level:** Choose a significance level (𝛼), commonly set at 0.05 or 0.01.
#
# 3. **Calculate the z-statistic:** Using the sample data, calculate the z-statistic.
#
# 4. **Determine Critical Value:** Identify the critical value(s) from the standard normal distribution that correspond to the significance level.
#
# 5. **Make a Decision:**
#
# If the calculated z-statistic falls into the critical region (beyond the critical values), reject the null hypothesis.
# If it does not, fail to reject the null hypothesis.
#
# **Conclusion**
#
# The z-statistic is a powerful tool in hypothesis testing, providing a standardized way to evaluate the likelihood of observing the sample data under the assumption that the null hypothesis is true. By relating sample statistics to the standard normal distribution, it helps in making informed decisions about statistical hypotheses.

# %% [markdown]
# ## **Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?**

# %% [markdown]
# Ans:- The p-value (probability value) is a measure that helps to determine the strength of the evidence against the null hypothesis (𝐻0) in hypothesis testing. It represents the probability of obtaining a test statistic at least as extreme as the one observed, assuming that the null hypothesis is true.
#
# ###**How P-Value is Used in Hypothesis Testing**
#
# **1.Formulate Hypotheses:**Define the null hypothesis (H0) and the alternative hypothesis (𝐻a).
#
# **2.Choose a Significance Level (α):** This is the threshold for determining whether to reject (𝐻0), commonly set at 0.05 or 0.01.
#
# **3.Calculate the Test Statistic:** Based on the sample data, calculate the appropriate test statistic (e.g., z-statistic, t-statistic).
#
# **4.Determine the P-Value:** Calculate the p-value corresponding to the test statistic.
#
# **5.Make a Decision:**
#
# * If the p-value is less than or equal to α, reject the null hypothesis.
# * If the p-value is greater than α, fail to reject the null hypothesis.
#
# ###**Interpretation of a Small P-Value**
# If the p-value is very small (e.g., 0.01), it indicates strong evidence against the null hypothesis. Specifically:
#
# * A p-value of 0.01 means there is only a 1% probability of observing the test results (or something more extreme) if the null hypothesis is true.
# Thus, a small p-value suggests that the sample data is inconsistent with the null hypothesis, leading to a decision to reject 𝐻0.
# * Thus, a small p-value suggests that the sample data is inconsistent with the null hypothesis, leading to a decision to reject 𝐻0.

# %% [markdown]
# ## **Question3: Compare and contrast the binomial and Bernoulli distributions**

# %% [markdown]
# The binomial and Bernoulli distributions are closely related but serve different purposes in probability and statistics. Here’s a comparison:
#
# **Bernoulli Distribution**
#
# * **Definition**: A Bernoulli distribution represents a single trial with two possible outcomes: "success" (usually coded as 1) and "failure" (coded as 0).
# * **Parameters**: It has one parameter, p, which is the probability of success on a single trial.
#
# * **Mean:** The mean (expected value) is
#          E(X)=p.
#
# **Variance**: The variance is
#
#         Var(X)=p(1−p).
#
# *  **Applications:** Used to model situations where there are only two outcomes, such as a coin flip or a yes/no survey question.
#
# **Binomial Distribution**
#
# * **Definition:** A binomial distribution models the number of successes in
# n independent Bernoulli trials.
#
# * **Parameters:** It has two parameters:
# n (the number of trials) and
# p (the probability of success on each trial).
#
# * **Mean**: The mean is
#
# #     E(X)=np
#
# * **Variance**: The variance is
#       Var(X)=np(1−p).
#
# * **Applications:** Useful for situations where you want to know the number of successes in a fixed number of trials, such as the number of heads in 10 coin flips.
#
# # **Comparison**
#
# **1.Nature of Distribution:**
#
# The Bernoulli distribution is for a single trial, while the binomial distribution encompasses multiple trials.
#
# **2.Parameters:**
#
# Bernoulli has one parameter (p), while binomial has two (n and p).
#
# **3.Outcomes:**
#
# The Bernoulli distribution has outcomes of 0 or 1, whereas the binomial distribution can take on integer values from 0 to n.
#
# **4.Mean and Variance:**
#
# The mean and variance formulas differ due to the number of trials involved.
#
# **Conclusion**
#
# While both distributions are fundamental in probability theory and statistics, the Bernoulli distribution is a special case of the binomial distribution where
# **n=1**. Understanding both is crucial for analyzing scenarios involving binary outcomes.

# %% [markdown]
# ## **Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?**

# %% [markdown]
# The binomial distribution is used under specific conditions that align closely with the properties of Bernoulli trials. Here are the key conditions and how it relates to the Bernoulli distribution:
#
# **Conditions for Using the Binomial Distribution**
#
# **1.Fixed Number of Trials:** There must be a predetermined number of trials,
# n.
#
# **2.Binary Outcomes:** Each trial must result in one of two outcomes: "success" or "failure."
#
# **3.Constant Probability:** The probability of success, denoted as
# p, must remain constant for each trial.
#
# **4.Independent Trials:** The trials must be independent; the outcome of one trial does not affect the outcomes of others.
#
# **Relationship to the Bernoulli Distribution**
#
# * **Special Case:** The binomial distribution can be thought of as a series of independent Bernoulli trials. Specifically, if you conduct a Bernoulli trial
# n times, the distribution of the number of successes follows a binomial distribution.
#
# * **Parameters:** While a Bernoulli distribution is characterized by a single parameter p(the probability of success), the binomial distribution includes both n (the number of trials) and p.
#
# * **Outcomes:** The Bernoulli distribution captures the result of one trial (either success or failure), whereas the binomial distribution counts the number of successes across all n trials.
#
# **Summary**
#
# In summary, the binomial distribution is applicable when you have multiple independent trials of a Bernoulli experiment, and it aggregates the outcomes over those trials. The properties and formulas of the binomial distribution naturally extend from those of the Bernoulli distribution, making them closely connected in statistical theory.

# %% [markdown]
# ## **Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?**

# %% [markdown]
# The Poisson distribution is a discrete probability distribution that is particularly useful for modeling the number of events occurring within a fixed interval of time or space. Here are the key properties and the appropriate conditions for using the Poisson distribution:
#
# **Key Properties of the Poisson Distribution**
#
# **1.Discrete Nature:** The Poisson distribution models the number of events, which can only take non-negative integer values (0, 1, 2, ...).
#
# **2.Parameter:** It is characterized by a single parameter λ (lambda), which represents the average number of events in a given interval. This parameter also serves as both the mean and variance of the distribution:
#
# * **Mean:**
#           E(X)=λ
# * **Variance:**
#           Var(X)=λ
#
# **3.Independence:** The events are assumed to occur independently of one another.
#
# **4.Constant Rate:** The average rate λ of occurrence is constant over time or space.
#
# **5.Rare Events:** The Poisson distribution is often used to model rare events where the probability of multiple occurrences in a very small interval is negligible.
#
# **When to Use the Poisson Distribution**
#
# **1.Fixed Interval:** Use the Poisson distribution when you're interested in counting the number of events in a fixed interval of time, area, or volume.
#
# **2.Low Probability of Individual Events:** It is appropriate when the individual events are rare compared to the total number of possibilities. For example, modeling the number of phone calls received at a call center in an hour.
#
# **3.Independence of Events:** The events should occur independently of each other. For instance, one customer's arrival should not influence another's.
#
# **4.Known Average Rate:** The average rate λ of occurrences should be known or can be reasonably estimated based on historical data.
#
# **Examples of Use Cases**
#
# * Number of emails received in an hour.
# * Number of accidents occurring at a traffic intersection in a day.
# * Number of decay events from a radioactive source in a given time period.
#
# **Summary**
#
# The Poisson distribution is a powerful tool for modeling count data, especially in scenarios where events are rare and occur independently. Its properties make it particularly suited for various real-world applications, especially in fields like telecommunications, traffic analysis, and quality control.

# %% [markdown]
# ## **Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)?**

# %% [markdown]
# Certainly! Let’s define these terms and explore the differences between a probability density function (PDF) and a probability mass function (PMF).
#
# **Probability Distribution**
#
# A probability distribution is a mathematical function that describes the likelihood of different outcomes in a random variable. It provides a complete description of the probabilities associated with all possible values of that variable.
#
# **Probability distributions can be classified into two main types:**
#
# **1.Discrete Probability Distribution:** Used for discrete random variables, which can take on a countable number of values (e.g., integers).
#
# **2.Continuous Probability Distribution:** Used for continuous random variables, which can take on any value within a given range.
#
# ## **Probability Density Function (PDF)**
#
# A probability density function (PDF) is a specific type of function used for continuous random variables. The PDF describes the likelihood of the variable falling within a particular range of values, rather than taking on a specific value.
#
# **Key characteristics of a PDF:**
#
# The area under the curve of the PDF over a given interval represents the probability of the random variable falling within that interval.
#
# The total area under the PDF curve across the entire space is equal to 1.
# The probability of the variable taking on a specific exact value is zero in continuous distributions.
#
# ##**Probability Mass Function (PMF)**
#
# A probability mass function (PMF) is used for discrete random variables. The PMF gives the probability that a discrete random variable is exactly equal to some value.
#
# **Key characteristics of a PMF:**
#
# It assigns a probability to each possible value of the discrete random variable.
# The sum of all probabilities for all possible values must equal 1.
#
# **Key Differences Between PDF and PMF**
#
# **1.Type of Variable:**
#
# PMF: Used for discrete random variables.
#
# PDF: Used for continuous random variables.
#
# **2.Probability Representation:**
#
# PMF: Provides the probability of a specific outcome (e.g.,
# P(X=x)).
#
# PDF: Gives the density of probabilities; to find the probability of the variable falling within an interval, you integrate the PDF over that interval (e.g., P(a<X<b)=∫ f(x)dx).
#
# **3.Values:**
#
# PMF: The values of a PMF are probabilities (between 0 and 1).
#
# PDF: The values of a PDF can be greater than 1, but the area under the curve must be 1.
#
# **Summary**
#
# In summary, a probability distribution provides a general framework for understanding probabilities associated with random variables, while a PDF and PMF serve specific roles for continuous and discrete variables, respectively. The PDF indicates the density of probabilities across a continuum, whereas the PMF gives precise probabilities for distinct outcomes.

# %% [markdown]
# ## **Question7: Explain the Central Limit Theorem (CLT) with example.**

# %% [markdown]
# The Central Limit Theorem (CLT) is a fundamental statistical principle that describes the distribution of sample means. It states that, given a sufficiently large sample size, the distribution of the sample means will tend to be normally distributed, regardless of the original distribution of the population from which the samples are drawn. Here are the key aspects of the CLT:
#
# ### Key Points of the Central Limit Theorem
#
# 1. **Sample Size**: The theorem applies when the sample size is sufficiently large. A common rule of thumb is that a sample size of \( n \geq 30 \) is generally considered adequate.
#
# 2. **Independence**: The samples should be independent of one another.
#
# 3. **Convergence to Normality**: As the sample size increases, the distribution of the sample means approaches a normal distribution with mean \( \mu \) (the mean of the population) and variance \( \sigma^2/n \) (where \( \sigma^2 \) is the population variance).
#
# ### Example of the Central Limit Theorem
#
# **Scenario**: Imagine you have a population of students at a university, and their exam scores are not normally distributed—let's say they are skewed to the right (more students score lower with fewer high scores).
#
# 1. **Population Characteristics**:
#    - Mean score (\( \mu \)): 70
#    - Standard deviation (\( \sigma \)): 15
#    - Distribution: Skewed right
#
# 2. **Sampling**: You take random samples of size \( n = 30 \) from this population and calculate the mean score for each sample.
#
# 3. **Repeated Sampling**: If you repeat this process many times (say, 1,000 samples), you will compile a distribution of the sample means.
#
# 4. **Observation**: According to the CLT:
#    - Even though the original exam scores are not normally distributed, the distribution of the sample means will be approximately normally distributed.
#    - The mean of this distribution of sample means will be close to the population mean (70).
#    - The standard deviation of the sample means (standard error) will be \( \sigma/\sqrt{n} = 15/\sqrt{30} \approx 2.74 \).
#
# 5. **Conclusion**: After plotting the distribution of the sample means, you will see that it resembles a normal distribution, allowing you to use normal distribution techniques (e.g., confidence intervals, hypothesis testing) for inference, even if the original population was not normally distributed.
#
# ### Importance of the Central Limit Theorem
#
# The CLT is crucial because it justifies the use of normal distribution methods in many statistical analyses, particularly when dealing with large samples. It allows researchers and statisticians to make inferences about population parameters based on sample statistics, facilitating hypothesis testing and confidence interval estimation.

# %% [markdown]
# ## **Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?**

# %% [markdown]
# Z-scores and t-scores are both standard scores used in statistics to describe how far a specific data point is from the mean in terms of standard deviations. However, they have different applications and are used under different conditions. Here’s a comparison:
#
# ### Z-Scores
#
# - **Definition**: A z-score measures the number of standard deviations a data point is from the mean of a population.
# - **Formula**:
#   \[
#   z = \frac{(X - \mu)}{\sigma}
#   \]
#   where \( X \) is the value, \( \mu \) is the population mean, and \( \sigma \) is the population standard deviation.
# - **Use Case**:
#   - **Population Known**: Use z-scores when the population standard deviation is known.
#   - **Sample Size**: Typically applied when the sample size is large (\( n \geq 30 \)) due to the Central Limit Theorem, which suggests that the sampling distribution of the mean is approximately normal regardless of the original population distribution.
#   - **Normal Distribution**: Ideal for data that follows a normal distribution.
#
# ### T-Scores
#
# - **Definition**: A t-score measures the number of standard deviations a data point is from the sample mean, using the sample standard deviation.
# - **Formula**:
#   \[
#   t = \frac{(X - \bar{X})}{s/\sqrt{n}}
#   \]
#   where \( \bar{X} \) is the sample mean, \( s \) is the sample standard deviation, and \( n \) is the sample size.
# - **Use Case**:
#   - **Population Unknown**: Use t-scores when the population standard deviation is unknown and must be estimated from the sample.
#   - **Sample Size**: Typically applied for smaller sample sizes (\( n < 30 \)), where the sample might not adequately represent the population.
#   - **Normality Assumption**: Used when the underlying population is assumed to be normally distributed, especially when the sample size is small.
#
# ### Summary of When to Use Each
#
# - **Use Z-Scores**:
#   - When the population standard deviation is known.
#   - When the sample size is large (\( n \geq 30 \)).
#   - When data is approximately normally distributed.
#
# - **Use T-Scores**:
#   - When the population standard deviation is unknown.
#   - When the sample size is small (\( n < 30 \)).
#   - When the underlying population is normally distributed, or the sample size is small enough that the t-distribution is more appropriate.
#
# ### Conclusion
#
# In summary, z-scores and t-scores are both useful for standardizing scores, but they are applied under different circumstances. Understanding when to use each is crucial for accurate statistical analysis and inference.

# %% [markdown]
# ## **Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis?**
#
# ### **Task: Write Python code to calculate the z-score and p-value for the given data.**
#
# ### **Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.**

# %% [markdown]
# To calculate the z-score and p-value for the given data, we can use the following steps:
#
# 1. **Calculate the z-score** using the formula:
#    \[
#    z = \frac{(X - \mu)}{\sigma / \sqrt{n}}
#    \]
#    where:
#    - \( X \) = sample mean (105)
#    - \( \mu \) = population mean (100)
#    - \( \sigma \) = population standard deviation (15)
#    - \( n \) = sample size (25)
#
# 2. **Calculate the p-value** based on the z-score.
#
# 3. **Determine whether to reject or fail to reject the null hypothesis** based on the significance level of 0.05.
#
# Here's how you can do this in Python:-

# %%
import scipy.stats as stats
import numpy as np

# Given data
X = 105  # sample mean
mu = 100  # population mean
sigma = 15  # population standard deviation
n = 25  # sample size

# Calculate the z-score
z = (X - mu) / (sigma / np.sqrt(n))
print(f"Z-score: {z}")

# Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z)))
print(f"P-value: {p_value}")

# Determine if we reject the null hypothesis
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-score: 1.6666666666666667
# P-value: 0.09558070454562939
# Fail to reject the null hypothesis.

# %% [markdown]
# ### Explanation of the Code:
# - We first import the necessary libraries: `scipy.stats` for statistical functions and `numpy` for numerical operations.
# - We define the variables based on the provided data.
# - We calculate the z-score using the formula.
# - We calculate the p-value using the cumulative distribution function (CDF) of the normal distribution.
# - Finally, we check if the p-value is less than the significance level (0.05) to decide whether to reject or fail to reject the null hypothesis.
#
# ### Interpretation:
# - The z-score will indicate how many standard deviations the sample mean is from the population mean.
# - The p-value will tell us the probability of observing a sample mean as extreme as the one we have (or more extreme) under the null hypothesis. If the p-value is less than 0.05, we reject the null hypothesis; otherwise, we fail to reject it.

# %% [markdown]
# ### **Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.**
# ###**Generate 1,000 samples and plot the distribution. What is the expected mean and variance?**
#
# **Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.**
#
# **Objective: Understand the properties of a binomial distribution and verify them through simulation.**

# %% [markdown]
# To simulate a binomial distribution with 10 trials and a probability of success of 0.6, we can use the `numpy` library to generate random samples and `matplotlib` to plot the distribution. We will generate 1,000 samples, calculate the mean and variance, and verify them against the expected values.
#
# Here’s how you can accomplish this in Python:
#
#
#
# ### Running the Code:
# You can run this code in a Python environment with `numpy`, `matplotlib`, and `seaborn` installed to visualize the binomial distribution and verify the mean and variance properties.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters for the binomial distribution
n = 10  # number of trials
p = 0.6  # probability of success
num_samples = 1000  # number of samples

# Generate binomial distribution samples
samples = np.random.binomial(n, p, num_samples)

# Calculate mean and variance
mean = np.mean(samples)
variance = np.var(samples)

# Expected mean and variance
expected_mean = n * p
expected_variance = n * p * (1 - p)

# Print results
print(f"Simulated Mean: {mean}")
print(f"Simulated Variance: {variance}")
print(f"Expected Mean: {expected_mean}")
print(f"Expected Variance: {expected_variance}")

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.histplot(samples, bins=np.arange(-0.5, n + 1.5, 1), kde=False, stat="density")
plt.title("Histogram of Binomial Distribution Samples")
plt.xlabel("Number of Successes")
plt.ylabel("Density")
plt.xticks(np.arange(0, n + 1, 1))
plt.grid(axis='y')
plt.show()
# Out:
# Simulated Mean: 5.979
# Simulated Variance: 2.4465589999999997
# Expected Mean: 6.0
# Expected Variance: 2.4000000000000004

# %% [markdown]
# ### Explanation of the Code:
#
# 1. **Import Libraries**: We import `numpy` for numerical operations and `matplotlib.pyplot` along with `seaborn` for plotting.
#
# 2. **Set Parameters**: We define the parameters for the binomial distribution, including the number of trials \( n \), the probability of success \( p \), and the number of samples to generate.
#
# 3. **Generate Samples**: We use `np.random.binomial` to generate 1,000 samples from the binomial distribution.
#
# 4. **Calculate Mean and Variance**: We compute the mean and variance of the generated samples using `np.mean` and `np.var`.
#
# 5. **Expected Values**: We calculate the expected mean and variance based on the formulas:
#    - Expected Mean: \( E(X) = n \times p \)
#    - Expected Variance: \( Var(X) = n \times p \times (1 - p) \)
#
# 6. **Plotting**: We create a histogram of the samples and use seaborn's `histplot` for better visualization. We set appropriate labels and title for the plot.
#
# ### Expected Results:
# - The simulated mean and variance should be close to the expected values calculated from the formulas. The plot will show the distribution of successes in the simulated binomial trials.
